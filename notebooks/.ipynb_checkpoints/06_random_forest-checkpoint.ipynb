# %%
import pandas as pd
import numpy as np
import joblib

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score,
    mean_absolute_percentage_error
)

import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# ## Step 2: Load Data
# Load the same feature-engineered dataset and perform exactly the same preprocessing as in Task 4.
# This is critical because model comparisons are only fair if all models use the same train/test split.

# %%
df = pd.read_csv(
    "../data/processed/ev_sales_feature_engineered.csv",
    parse_dates=["Date"]
)

# %% [markdown]
# 2.3 One-Hot Encode the Categorical Columns

# %%
df = pd.get_dummies(
    df,
    columns=["State", "Vehicle_Category"],
    drop_first=True,
    dtype=int
)

# %% [markdown]
# 2.4 Create Features and Target

# %%
X = df.drop(
    columns=[
        "Date",
        "EV_Sales",
        "Month_Name",
        "Year_Month"
    ]
)

y = df["EV_Sales"]

# %% [markdown]
# 2.5 Create the Same Train/Test Split

# %%
split_index = int(len(df) * 0.8)

X_train = X.iloc[:split_index]
X_test = X.iloc[split_index:]

y_train = y.iloc[:split_index]
y_test = y.iloc[split_index:]

# %% [markdown]
# 2.6 Verify

# %%
print("Training Data :", X_train.shape)
print("Testing Data  :", X_test.shape)

print("Target Train :", y_train.shape)
print("Target Test  :", y_test.shape)
# Out:
# Training Data : (230, 14)
# Testing Data  : (58, 14)
# Target Train : (230,)
# Target Test  : (58,)

# %% [markdown]
# ## Step 3: Train the Model

# %%
rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, n_jobs=-1, random_state=42)

# %%
y_pred = rf.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)

# %%
print(f"MAE  : {mae:.2f}")
print(f"MSE  : {mse:.2f}")
print(f"RMSE : {rmse:.2f}")
print(f"R²   : {r2:.4f}")
print(f"MAPE : {mape:.4f}")
# Out:
# MAE  : 121.42
# MSE  : 30272.22
# RMSE : 173.99
# R²   : 0.9964
# MAPE : 0.0675

# %% [markdown]
# Step 6: Actual vs Predicted

# %%
results = pd.DataFrame({
    "Actual": y_test,
    "Predicted": y_pred
})

results.head()
# Out:
#      Actual  Predicted
# 230    6100    5617.05
# 231    5850    6180.85
# 232    6400    6380.00
# 233    6900    6954.50
# 234    7350    7472.50

# %%
fig = px.line(
    results.reset_index(drop=True),
    y=["Actual", "Predicted"],
    title="Actual vs Predicted EV Sales"
)

fig.show()

# %% [markdown]
# ## Step 7: Feature Importance
# One of the biggest advantages of Random Forest is that it tells you which features matter most.

# %%
importance = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance": rf.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance.head(15)
# Out:
#                          Feature  Importance
# 6                      Rolling_3    0.583643
# 3                          Lag_1    0.364362
# 4                          Lag_2    0.026488
# 5                          Lag_3    0.012329
# 13  Vehicle_Category_Electric 4W    0.004627
# 12  Vehicle_Category_Electric 3W    0.002778
# 7                  Rolling_STD_3    0.001519
# 8                     MoM_Growth    0.001439
# 10             State_Maharashtra    0.001177
# 1                          Month    0.000924
# 9                State_Karnataka    0.000389
# 2                        Quarter    0.000161
# 11           State_Uttar Pradesh    0.000131
# 0                           Year    0.000034

# %%
fig = px.bar(
    importance.head(15),
    x="Importance",
    y="Feature",
    orientation="h",
    title="Top 15 Important Features"
)

fig.show()

# %%
joblib.dump(
    rf,
    "../models/random_forest.pkl"
)
# Out:
# ['../models/random_forest.pkl']
