# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    "../data/processed/ev_sales_cleaned.csv",
    parse_dates=["Date"]
)

df.head()
# Out:
#         Date  Year  Month      State Vehicle_Category  EV_Sales
# 0 2021-01-01  2021      1      Delhi      Electric 2W      2300
# 1 2021-01-01  2021      1      Delhi      Electric 3W      2100
# 2 2021-01-01  2021      1      Delhi      Electric 4W       700
# 3 2021-01-01  2021      1  Karnataka      Electric 2W      3100
# 4 2021-01-01  2021      1  Karnataka      Electric 3W      1200

# %% [markdown]
# ## Sort the Dataset
# - This is essential before creating lag features.

# %%
df = df.sort_values(
    ["State", "Vehicle_Category", "Date"]
).reset_index(drop=True)

# %% [markdown]
# **Step 4: Create Time-Based Features**

# %%
df["Quarter"] = df["Date"].dt.quarter

df["Month_Name"] = df["Date"].dt.month_name()

df["Year_Month"] = df["Date"].dt.to_period("M").astype(str)

# %%
df
# Out:
#           Date  Year  Month          State Vehicle_Category  EV_Sales  \
# 0   2021-01-01  2021      1          Delhi      Electric 2W      2300
# 1   2021-02-01  2021      2          Delhi      Electric 2W      2450
# 2   2021-03-01  2021      3          Delhi      Electric 2W      2860
# 3   2021-04-01  2021      4          Delhi      Electric 2W      2700
# 4   2021-05-01  2021      5          Delhi      Electric 2W      3020
# ..         ...   ...    ...            ...              ...       ...
# 283 2022-08-01  2022      8  Uttar Pradesh      Electric 4W      1840
# 284 2022-09-01  2022      9  Uttar Pradesh      Electric 4W      2020
# 285 2022-10-01  2022     10  Uttar Pradesh      Electric 4W      2300
# 286 2022-11-01  2022     11  Uttar Pradesh      Electric 4W      2520
# 287 2022-12-01  2022     12  Uttar Pradesh      Electric 4W      2700
#
#      Quarter Month_Name Year_Month
# 0          1    January    2021-01
# 1          1   February    2021-02
# ...

# %% [markdown]
# **Step 5: Create Lag Features**
# - These allow the model to use previous months' sales.

# %%
df["Lag_1"] = (
    df.groupby(["State", "Vehicle_Category"])["EV_Sales"]
      .shift(1)
)

df["Lag_2"] = (
    df.groupby(["State", "Vehicle_Category"])["EV_Sales"]
      .shift(2)
)

df["Lag_3"] = (
    df.groupby(["State", "Vehicle_Category"])["EV_Sales"]
      .shift(3)
)

# %% [markdown]
# **Step 6: Create Rolling Mean**

# %%
df["Rolling_3"] = (
    df.groupby(["State", "Vehicle_Category"])["EV_Sales"]
      .transform(lambda x: x.rolling(3).mean())
)

# %%
df["Rolling_STD_3"] = (
    df.groupby(["State", "Vehicle_Category"])["EV_Sales"]
      .transform(lambda x: x.rolling(3).std())
)

# %%
df["MoM_Growth"] = (
    df.groupby(["State", "Vehicle_Category"])["EV_Sales"]
      .pct_change() * 100
)

# %% [markdown]
# **Step 9: Handle Missing Values**
# The first few rows in each state/vehicle group will have missing lag and rolling values. Fill them with 0 for the ML models.

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Date                0
# Year                0
# Month               0
# State               0
# Vehicle_Category    0
# EV_Sales            0
# Quarter             0
# Month_Name          0
# Year_Month          0
# Lag_1               0
# Lag_2               0
# Lag_3               0
# Rolling_3           0
# Rolling_STD_3       0
# MoM_Growth          0
# dtype: int64

# %% [markdown]
# **Step 10: Verify the New Features**

# %%
df.head(10)
# Out:
#         Date  Year  Month  State Vehicle_Category  EV_Sales  Quarter  \
# 0 2021-01-01  2021      1  Delhi      Electric 2W      2300        1
# 1 2021-02-01  2021      2  Delhi      Electric 2W      2450        1
# 2 2021-03-01  2021      3  Delhi      Electric 2W      2860        1
# 3 2021-04-01  2021      4  Delhi      Electric 2W      2700        2
# 4 2021-05-01  2021      5  Delhi      Electric 2W      3020        2
# 5 2021-06-01  2021      6  Delhi      Electric 2W      3250        2
# 6 2021-07-01  2021      7  Delhi      Electric 2W      3400        3
# 7 2021-08-01  2021      8  Delhi      Electric 2W      3620        3
# 8 2021-09-01  2021      9  Delhi      Electric 2W      3890        3
# 9 2021-10-01  2021     10  Delhi      Electric 2W      4350        4
#
#   Month_Name Year_Month   Lag_1   Lag_2   Lag_3    Rolling_3  Rolling_STD_3  \
# 0    January    2021-01     0.0     0.0     0.0     0.000000       0.000000
# ...

# %%
df.to_csv(
    "../data/processed/ev_sales_feature_engineered.csv",
    index=False
)
